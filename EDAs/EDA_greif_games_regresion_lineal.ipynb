# %% [markdown]
# # EDA (Exploratory Data Analisys)

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-a9d3beb9-d607-4587-9fd2-53778da7cde6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9d3beb9-d607-4587-9fd2-53778da7cde6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import seaborn as sns

data = pd.read_csv("vgsales.csv")


data.info()

data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# ...

# %%
data['Publisher'].value_counts()
# Out:
# Publisher
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Warp                               1
# New                                1
# Elite                              1
# Evolution Games                    1
# UIG Entertainment                  1
# Name: count, Length: 578, dtype: int64

# %%
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
data.value_counts('Genre')/16598*100

data['Genre'].value_counts().plot(kind='pie',autopct='%.1f%%', title='Distribución torneos')
# Out:
# <Axes: title={'center': 'Distribución torneos'}, ylabel='count'>

# %%
data.head(6)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                    Tetris       GB  1989.0        Puzzle  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26

# %%
data.shape
# Out:
# (16598, 11)

# %%
## Declaramos valores para el eje x
eje_x = data['Year']

## Declaramos valores para el eje y
eje_y = data['Global_Sales']

## Creamos Gráfica
plt.bar(eje_x, eje_y, color="blue")

plt.rcParams["figure.figsize"] = (10, 6)

## Legenda en el eje y
plt.ylabel('seleccion')

## Legenda en el eje x
plt.xlabel('ranking')

## Título de Gráfica
plt.title('año con mas ventas')


plt.show()

# %%
fig = sns.boxplot(x= data['Platform'], y=data['Year'])

# %%
data.value_counts('Publisher')/16598*100
# Out:
# Publisher
# Electronic Arts                 8.139535
# Activision                      5.874202
# Namco Bandai Games              5.615134
# Ubisoft                         5.548861
# Konami Digital Entertainment    5.012652
#                                   ...
# Playmates                       0.006025
# Playmore                        0.006025
# Plenty                          0.006025
# Pony Canyon                     0.006025
# SCS Software                    0.006025
# Name: count, Length: 578, dtype: float64

# %%
sns.heatmap(data.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# # Regresion Lineal Multiple

# %%
data_regresion_lineal_multiple= data[['NA_Sales', 'JP_Sales', 'Global_Sales']]
data_regresion_lineal_multiple.head()
# Out:
#    NA_Sales  JP_Sales  Global_Sales
# 0        41         3            82
# 1        29         6            40
# 2        15         3            35
# 3        15         3            33
# 4        11        10            31

# %%
import pandas as pd                                # Se trabaja todo lo que es la estructura de los datos
import statsmodels.formula.api as smf              # Permite ajustar modelos estadísticos utilizando fórmulas de estilo R
import numpy as np                                 # representa matrices multidimensionales, equivalentes a las matrices del R
from matplotlib import pyplot                      # Permite la generación de gráficos
from mpl_toolkits.mplot3d import Axes3D            # Permite agregar eje tridimensionales
from sklearn.linear_model import LinearRegression  # sklearn es una libreria que cuenta con algoritmos de clasificación, regresión, clustering y reducción de dimensionalidad
from sklearn import metrics                        # sklearn es una libreria que cuenta con algoritmos de clasificación, regresión, clustering y reducción de dimensionalidad

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Suponiendo que 'data' es tu DataFrame que contiene las columnas 'NA_Sales', 'JP_Sales' y 'Global_Sales'

# Convertir las columnas de tipo float a int si es necesario
data['NA_Sales'] = data['NA_Sales'].astype(int)
data['JP_Sales'] = data['JP_Sales'].astype(int)
data['Global_Sales'] = data['Global_Sales'].astype(int)

# Crear la figura y el eje 3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Extraer datos de las columnas
x1 = data['NA_Sales']      # Ventas en Norte América (eje X)
x2 = data['JP_Sales']      # Ventas en Japón (eje Y)
y = data['Global_Sales']   # Ventas Globales (eje Z)

# Graficar el diagrama de dispersión tridimensional
ax.scatter(x1, x2, y, marker='*', c='r')

# Etiquetas de los ejes
ax.set_xlabel('Ventas en Norte América')
ax.set_ylabel('Ventas en Japón')
ax.set_zlabel('Ventas Globales')

# Mostrar la gráfica
plt.show()

# %%
data_regresion_lineal_multiple.corr()   # Podemos observar un alto indice de correlacion entre cada variable
# Out:
#               NA_Sales  JP_Sales  Global_Sales
# NA_Sales      1.000000  0.458591      0.922143
# JP_Sales      0.458591  1.000000      0.594700
# Global_Sales  0.922143  0.594700      1.000000

# %%
reg = smf.ols('NA_Sales ~ JP_Sales + Global_Sales',data=data_regresion_lineal_multiple)   # Se establece la regrecion con el Ordinary Least Square dictando que el consumo
res = reg.fit()                                                                           # va a ser aproximandamente igual a la suma del cilindraje y potencia.

# %%
print(res.summary())    # Imprimimos los resultados
print(res.rsquared)
print(res.params)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               NA_Sales   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                 5.219e+04
# Date:                Fri, 10 May 2024   Prob (F-statistic):               0.00
# Time:                        17:42:34   Log-Likelihood:                -2337.9
# No. Observations:               16598   AIC:                             4682.
# Df Residuals:                   16595   BIC:                             4705.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.0315      0.002    -14.280      0.000      -0.036      -0.027
# ...

# %%
lm = LinearRegression()
X = data_regresion_lineal_multiple[['NA_Sales','JP_Sales']]
lm.fit(X,y)
prediccion = lm.predict(X)
a = lm.intercept_
b = lm.coef_

# %%
b
# Out:
# array([1.64276822, 1.30338189])

# %%
print('Prediccion')
print('*'*100)
print(prediccion)     # Valores segun la prediccion
print('*'*100)
print(y)              # Valores actuales del consumo
print(lm.score(X,y))  # Retornamos el coeficiente de determinacion en la prediccion
# Out:
# Prediccion
# ****************************************************************************************************
# [71.35128126 55.5482083  28.63930759 ...  0.08763867  0.08763867
#   0.08763867]
# ****************************************************************************************************
# 0        82
# 1        40
# 2        35
# 3        33
# 4        31
#          ..
# 16593     0
# 16594     0
# 16595     0
# 16596     0
# 16597     0
# Name: Global_Sales, Length: 16598, dtype: int64
# 0.8877285431161032

# %%
resultados ={'Real':data_regresion_lineal_multiple['Global_Sales'],'Prediccion':prediccion}
result = pd.DataFrame(data=resultados)
print(result)
# Out:
#        Real  Prediccion
# 0        82   71.351281
# 1        40   55.548208
# 2        35   28.639308
# 3        33   28.639308
# 4        31   31.191908
# ...     ...         ...
# 16593     0    0.087639
# 16594     0    0.087639
# 16595     0    0.087639
# 16596     0    0.087639
# 16597     0    0.087639
#
# [16598 rows x 2 columns]

# %%
ECM = metrics.mean_squared_error(data_regresion_lineal_multiple['Global_Sales'],prediccion)
print(ECM)         # Error estandar
r_cuadrado = metrics.r2_score(data_regresion_lineal_multiple['Global_Sales'],prediccion)
print(r_cuadrado)  # R cuandrado o coeficiente de determinacion
# Out:
# 0.2534476713027848
# 0.8877285431161032

# %%
# Crear la figura y el eje 3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Extraer datos de las columnas
x1 = data['NA_Sales']      # Ventas en Norte América (eje X)
x2 = data['JP_Sales']      # Ventas en Japón (eje Y)
y = data['Global_Sales']   # Ventas Globales (eje Z)

# Graficar el diagrama de dispersión tridimensional
ax.scatter(x1, x2, y, marker='*', c='r')
# Datos segun la prediccion
ax.scatter(x1, x2, prediccion, marker='+', c='b')
# Etiquetas de los ejes
ax.set_xlabel('Ventas en Norte América')
ax.set_ylabel('Ventas en Japón')
ax.set_zlabel('Ventas Globales')

# Mostrar la gráfica
plt.show()
