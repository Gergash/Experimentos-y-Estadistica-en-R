# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-e4694285-a976-433f-b509-33284f650e84" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4694285-a976-433f-b509-33284f650e84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving vgsales.csv to vgsales.csv
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import seaborn as sns

data = pd.read_csv("vgsales.csv")


data.info()

data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# ...

# %% [markdown]
# ### 1-Pregunta a responder: Cual fue el genero de videojuegos mas exitoso de todos los tiempos?

# %%
data['Publisher'].value_counts()
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Warp                               1
# New                                1
# Elite                              1
# Evolution Games                    1
# UIG Entertainment                  1
# Name: Publisher, Length: 578, dtype: int64

# %%
data['Platform'].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
data.shape
# Out:
# (16598, 11)

# %%
data['Genre'].value_counts().plot(kind='bar', title='Genero mas popular',figsize=(10,3))

# %%
data.value_counts('Genre')/16598*100

data['Genre'].value_counts().plot(kind='pie',autopct='%.1f%%', title='Distribución torneos')

# %%
data['Platform'].value_counts().plot(kind='bar', title='plataforma mas popular',figsize=(10,3))

# %%
## Declaramos valores para el eje x
eje_x = data['Platform']

## Declaramos valores para el eje y
eje_y = data['Global_Sales']

## Creamos Gráfica
plt.barh(eje_x, eje_y, color="black")

plt.rcParams["figure.figsize"] = (10, 6)

## Legenda en el eje y
plt.ylabel('Plataforma')

## Legenda en el eje x
plt.xlabel('Dinero')

## Título de Gráfica
plt.title('plataforma con mas ventas')


plt.show()

# %%
data.shape
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
data.value_counts('Publisher')/16598*100
# Out:
# Publisher
# Electronic Arts                 8.139535
# Activision                      5.874202
# Namco Bandai Games              5.615134
# Ubisoft                         5.548861
# Konami Digital Entertainment    5.012652
#                                   ...
# Playmates                       0.006025
# Playmore                        0.006025
# Plenty                          0.006025
# Pony Canyon                     0.006025
# SCS Software                    0.006025
# Length: 578, dtype: float64

# %%
## Declaramos valores para el eje x
eje_x = data['Year']

## Declaramos valores para el eje y
eje_y = data['Global_Sales']

## Creamos Gráfica
plt.bar(eje_x, eje_y, color="blue")

plt.rcParams["figure.figsize"] = (10, 6)

## Legenda en el eje y
plt.ylabel('seleccion')

## Legenda en el eje x
plt.xlabel('ranking')

## Título de Gráfica
plt.title('año con mas ventas')


plt.show()

# %%
## Declaramos valores para el eje x
eje_x = data['Genre']

## Declaramos valores para el eje y
eje_y = data['Global_Sales']

## Creamos Gráfica
plt.bar(eje_x, eje_y, color="red")

plt.rcParams["figure.figsize"] = (15, 8)

## Legenda en el eje y
plt.ylabel('seleccion')

## Legenda en el eje x
plt.xlabel('ranking')

## Título de Gráfica
plt.title('año con mas ventas')


plt.show()

# %%
import statsmodels.api as sm
import seaborn as sb

figsize=(10,5)

corr = data.set_index('Genre').corr()
fig = sm.graphics.plot_corr(corr, xnames=list(corr.columns))

fig.set_figheight(6)
fig.set_figwidth(8)

plt.show()

# %%
sb.scatterplot(data=data, x= 'Year', y='Global_Sales')

# %%
data2= data[['Year', 'NA_Sales', 'EU_Sales', 'JP_Sales','Global_Sales']]
data2.head()
# Out:
#      Year  NA_Sales  EU_Sales  JP_Sales  Global_Sales
# 0  2006.0     41.49     29.02      3.77         82.74
# 1  1985.0     29.08      3.58      6.81         40.24
# 2  2008.0     15.85     12.88      3.79         35.82
# 3  2009.0     15.75     11.01      3.28         33.00
# 4  1996.0     11.27      8.89     10.22         31.37

# %%
sb.pairplot(data2, kind='reg')

# %%
fig = sb.boxplot(x= data['Platform'], y=data['Year'])

# %%
data.groupby(['Genre'])['Global_Sales', 'Year'].agg(['mean','median', 'var', 'std'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#              Global_Sales                                    Year          \
#                      mean median       var       std         mean  median
# Genre
# Action           0.528100  0.190  1.337324  1.156427  2007.909929  2009.0
# Adventure        0.185879  0.060  0.263456  0.513280  2008.130878  2009.0
# Fighting         0.529375  0.210  0.913868  0.955965  2004.630383  2005.0
# Misc             0.465762  0.160  1.728925  1.314886  2007.258480  2008.0
# Platform         0.938341  0.280  6.683540  2.585254  2003.820776  2004.0
# Puzzle           0.420876  0.110  2.438958  1.561716  2005.243433  2007.0
# Racing           0.586101  0.190  2.763697  1.662437  2004.840131  2005.0
# ...

# %%
fig = sb.boxplot(x='Platform', y='Year', data=data)
fig = sb.swarmplot(x='Platform', y='Year', data=data, color='black', alpha = 0.5);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 93.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 45.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 41.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 96.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
data.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
sb.heatmap(data.isnull(), cbar=False)

# %%
sb.pairplot(data, hue='Genre')
